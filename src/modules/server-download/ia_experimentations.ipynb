# %%
# %pip install langchain==0.0.163
# %pip install pygpt4all==1.1.0
# %pip install sentence_transformers
# %pip install chromadb==0.3.23
# Out:
# Requirement already satisfied: langchain==0.0.163 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (0.0.163)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from langchain==0.0.163) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from langchain==0.0.163) (2.0.15)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from langchain==0.0.163) (3.8.4)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from langchain==0.0.163) (0.5.7)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from langchain==0.0.163) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from langchain==0.0.163) (1.23.5)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from langchain==0.0.163) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from langchain==0.0.163) (1.10.8)
# Requirement already satisfied: requests<3,>=2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from langchain==0.0.163) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from langchain==0.0.163) (8.2.2)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from langchain==0.0.163) (4.65.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.163) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.163) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.163) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.163) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.163) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.163) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.163) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.163) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.163) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.163) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from pydantic<2,>=1->langchain==0.0.163) (4.6.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain==0.0.163) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain==0.0.163) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain==0.0.163) (2023.5.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.163) (2.0.2)
# Requirement already satisfied: colorama in c:\users\pierre\appdata\roaming\python\python311\site-packages (from tqdm>=4.48.0->langchain==0.0.163) (0.4.6)
# Requirement already satisfied: packaging>=17.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.163) (21.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.163) (1.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.163) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pygpt4all==1.1.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (1.1.0)
# Requirement already satisfied: pyllamacpp in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from pygpt4all==1.1.0) (2.4.0)
# Requirement already satisfied: pygptj in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from pygpt4all==1.1.0) (2.0.3)
# Requirement already satisfied: numpy in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from pygptj->pygpt4all==1.1.0) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sentence_transformers in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (4.14.1)
# Requirement already satisfied: tqdm in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (2.0.1)
# Requirement already satisfied: torchvision in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (0.15.2)
# Requirement already satisfied: numpy in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: nltk in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence_transformers) (0.15.1)
# Requirement already satisfied: filelock in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.0)
# Requirement already satisfied: fsspec in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.5.0)
# Requirement already satisfied: requests in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.6.3)
# Requirement already satisfied: packaging>=20.9 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (21.3)
# Requirement already satisfied: sympy in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: colorama in c:\users\pierre\appdata\roaming\python\python311\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.5.5)
# Requirement already satisfied: sacremoses in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.0.53)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.10.3)
# Requirement already satisfied: click in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: joblib in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from torchvision->sentence_transformers) (9.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence_transformers) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.5.7)
# Requirement already satisfied: six in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: chromadb==0.3.23 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (0.3.23)
# Requirement already satisfied: pandas>=1.3 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (2.0.2)
# Requirement already satisfied: requests>=2.28 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (1.10.8)
# Requirement already satisfied: hnswlib>=0.7 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (0.7.0)
# Requirement already satisfied: clickhouse-connect>=0.5.7 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (0.5.25)
# Requirement already satisfied: sentence-transformers>=2.2.2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (2.2.2)
# Requirement already satisfied: duckdb>=0.7.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (0.8.0)
# Requirement already satisfied: fastapi>=0.85.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (0.95.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (0.22.0)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (1.23.5)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (3.0.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from chromadb==0.3.23) (4.6.3)
# Requirement already satisfied: certifi in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.23) (2023.5.7)
# Requirement already satisfied: urllib3>=1.26 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.23) (1.26.16)
# Requirement already satisfied: pytz in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.23) (2023.3)
# Requirement already satisfied: zstandard in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.23) (0.21.0)
# Requirement already satisfied: lz4 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.23) (4.3.2)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from fastapi>=0.85.1->chromadb==0.3.23) (0.27.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3->chromadb==0.3.23) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3->chromadb==0.3.23) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb==0.3.23) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb==0.3.23) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb==0.3.23) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.28->chromadb==0.3.23) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.28->chromadb==0.3.23) (3.4)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers>=2.2.2->chromadb==0.3.23) (4.14.1)
# Requirement already satisfied: tqdm in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers>=2.2.2->chromadb==0.3.23) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers>=2.2.2->chromadb==0.3.23) (2.0.1)
# Requirement already satisfied: torchvision in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers>=2.2.2->chromadb==0.3.23) (0.15.2)
# Requirement already satisfied: scikit-learn in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers>=2.2.2->chromadb==0.3.23) (1.2.2)
# Requirement already satisfied: scipy in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers>=2.2.2->chromadb==0.3.23) (1.10.1)
# Requirement already satisfied: nltk in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers>=2.2.2->chromadb==0.3.23) (3.8.1)
# Requirement already satisfied: sentencepiece in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers>=2.2.2->chromadb==0.3.23) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers>=2.2.2->chromadb==0.3.23) (0.15.1)
# Requirement already satisfied: click>=7.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.23) (8.1.3)
# Requirement already satisfied: h11>=0.8 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.23) (0.14.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\pierre\appdata\roaming\python\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.23) (0.4.6)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.23) (0.5.0)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.23) (1.0.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.23) (6.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.23) (0.19.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.23) (11.0.3)
# Requirement already satisfied: filelock in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (3.12.0)
# Requirement already satisfied: fsspec in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (2023.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (21.3)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from starlette<0.28.0,>=0.27.0->fastapi>=0.85.1->chromadb==0.3.23) (3.7.0)
# Requirement already satisfied: sympy in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (1.12)
# Requirement already satisfied: networkx in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (3.1)
# Requirement already satisfied: jinja2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (2023.5.5)
# Requirement already satisfied: sacremoses in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (0.0.53)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (0.10.3)
# Requirement already satisfied: joblib in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from nltk->sentence-transformers>=2.2.2->chromadb==0.3.23) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers>=2.2.2->chromadb==0.3.23) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from torchvision->sentence-transformers>=2.2.2->chromadb==0.3.23) (9.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.85.1->chromadb==0.3.23) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\pierre\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb==0.3.23) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.document_loaders import TextLoader
from langchain.text_splitter import TextSplitter 
from typing import Any, List

class CustomTextSplitter(TextSplitter):
    def __init__(self, **kwargs: Any):
        super().__init__(**kwargs)

    def split_text(self, text: str) -> List[str]:
        splits = text.split('\n')
        return splits


docs = TextLoader('../../../saved/generated_save.txt').load()
print("Loaded docs")

sub_docs = CustomTextSplitter(chunk_size = 1494, chunk_overlap  = 20).split_documents(docs)

for page in sub_docs:
    print("##################### PAGE #####################\n", page.page_content)
# Out:
# Loaded docs
# ##################### PAGE #####################
#  Salut les gens. Voici un early prototype de mon prochain jeu provisoirement appele Embuscade 2 (La "suite" de Embuscade) Les interesses peuvent telecharger le jeu et m'envoyer leur review accompagne d'un screencast Voici le lien de telechargement :  Si celui ci ne fonctionne pas, essayez directement celui la :
# ##################### PAGE #####################
#  Petit Readme.txt au cas ou vous n'arrivez pas  le telecharger
# ##################### PAGE #####################
#  Vous pouvez aussi tester "Embuscade" (le 1, donc) dans le chan <#441274712417632267>
# ##################### PAGE #####################
#  C'est bon, tu es chez toi ^^
# ##################### PAGE #####################
#  Tu peux modifier le nom du chan et epingler des message
# ##################### PAGE #####################
#  Genial! Merci beaucoup
# ##################### PAGE #####################
#  Salut salut J'ai repare quelques bugs sur le prototype, Je le remet  jour tout  l'heure.  Log :  - parfois les Zombies n'attaquaient pas  - erreurs lorsqu'un humain infecte se transformait en Zombie trop proche d'un autre humain en vie (silencieux)  - feedback de dommages trop courts (je l'ai passe  de 0.1s 0 0.25s)  - les feedback de dommages des zombies sont maintenant d'une differente couleur de ceux des humains (ameliore a comprehension du combat)  Juste pour info, l'Alpha-test prendra fin la semaine prochaine.
# ##################### PAGE #####################
#  Quick Update : La production d'asset a demarre
# ##################### PAGE #####################
#  Tu arrives anime les voxel apres ?
# ##################### PAGE #####################
#  Oui, je vais faire un Rig. Je vais separer quelques parties afin de ne pas trop deformer le modele. Le resultat sera ce que j'appel du soft voxel, ou Voxel mou en FR.
# ##################### PAGE #####################
#  Ok ^^
# ##################### PAGE #####################
#  C'est quoi ton soft pour faire ca ?
# ##################### PAGE #####################
#  du Moxel en fr
# ##################### PAGE #####################
#  ou Mouxel
# ##################### PAGE #####################
#  je l'avais dej fait dans mon precedent projet (Embuscade) Le process etait moins long que de creer un model par pose (comme pour du pixel art) et c'etait assez chouette, je garde donc le process :) Du MOUXEL!! Exact! haha, bien trouve ca, pose un brevet la dessus
# ##################### PAGE #####################
#    c'est magicaVoxel
# ##################### PAGE #####################
#  C'est gratuit ?
# ##################### PAGE #####################
#  Yes
# ##################### PAGE #####################
#  Et ca exporte en polygonal ?
# ##################### PAGE #####################
#  sympa le soft clair
# ##################### PAGE #####################
#  Ptn, je vais m'en servir pour mon projet ca c'est sur
# ##################### PAGE #####################
#    je le recommande honetement  tous ceux qui sont interesse par du voxel / pixel art
# ##################### PAGE #####################
#  ha ouais il y a meme des templates
# ##################### PAGE #####################
#  Yes, et c'est possible d'exporter en plusieurs formats donc le OBJ. Les textures sont directement gardees  l'import dans UE4
# ##################### PAGE #####################
#  et tu dit que tu les rig apres ?
# ##################### PAGE #####################
#  mais dansle meme soft
# ##################### PAGE #####################
#  ?
# ##################### PAGE #####################
#  Non par contre. Le rig peut tres bien se faire dans Mixamo directement si jamais vous n'utilisez pas 3ds ou ce genre de soft. Le model doit peut etre etre un peut retravaille avant au niveau de la topologie, ca depend.
# ##################### PAGE #####################
#  alors. J'espere que tu me vouvoies  pas    J'utilise Blender (enfin je commence donc pas de maniere si pousse encore) et j'ai dej utilise mixamo pour faire du bricolage avec des charactere deja fait
# ##################### PAGE #####################
#  merci pour les infos. Et bon travail
# ##################### PAGE #####################
#  Haha! Non t'inquietes je parlais vous au pluriel XD Ah t'utilises blender? Cool, alors ca irait pour retoucher la topo du model avant import dans mixamo. Au cas ou yaurais besoin.  Derien, Merci pour le soutien
# ##################### PAGE #####################
#  Comment ca retopo un perso en voxel ?
# ##################### PAGE #####################
#  normalement le voxel c'est hyper simpliste, pas besoin de retopo
# ##################### PAGE #####################
#  En fait a l'export en OBJ. il triangulise tout et la topo n'est pas tres clean. Par contre tu peut aussi tout exporter en cube. Je ne me rapelle plus du format d'export mais c'est possible, c'est juste que c'est pas tres optimise. Apres encore une fois tout depend du model. Si c'est un perso genre chibi ca pose pas de probleme de garder les voxels.
# ##################### PAGE #####################
#  De toute facon,  l'import dans UE4, le model est triangularise donc ca n'importe peu
# ##################### PAGE #####################
#  oui mais c'est triangule de cette maniere en fait si tu veux :
# ##################### PAGE #####################
#  en sauvage quoi XD
# ##################### PAGE #####################
#  ah
# ##################### PAGE #####################
#  ouais
# ##################### PAGE #####################
#  un peu bizarre leur maniere de faire ca
# ##################### PAGE #####################
#  pas tres opti tout ca
# ##################### PAGE #####################
#  Non c'est une topo atroce. Pour ca que je parlais de retopo avant de passer direct  mixamo, L'export OBJ de magica n'est pas exploitable tel quel en animation
# ##################### PAGE #####################
#  Et surtout peu optimise pour les jeux
# ##################### PAGE #####################
#  non ?
# ##################### PAGE #####################
#  Pas optimise du tout meme   . Je ne pense pas que Magica optimise quoi que ce soit. Il exporte en OBJ, decoupe les faces en fonction des couleurs des voxels et c'est tout. Il ne soude meme pas les vertex, il faut le faire dans un soft 3D. C'est vraiment juste un moyen de recuperer le travail dans un soft 3D.  C'est l'algorythme derriere l'OBJ qui triangule les faces, parce que tel quel elles seraient en fait des n-gones. Mais l'OBJ ne supporte pas les n-gones donc il triangule. Il y a d'autre methodes d'export mais je ne les ai pas utilise car ce sont soit des formats pas compatibles 3ds, soit c'est plein de petits cubes ce qui est encore plus chiant  optimiser par la suite.
# ##################### PAGE #####################
#  Du coup, certe, bosser en voxel demande quand meme un travail supplementaire de topologie par la suite. Ca fait parti du workflow quoi. Sauf si on est pret a accepter les petits cubes par milliers ou une topo atroce plein d'artefact
# ##################### PAGE #####################
#  Nouveau post sur le devlog
# ##################### PAGE #####################
#  voila le resultat des Zeds de tout  l'heure
# ##################### PAGE #####################
#  Brainzz
# ##################### PAGE #####################
#  J'adore
# ##################### PAGE #####################
#  Tes zombies sont vraiment trop cool mec
# ##################### PAGE #####################
#  Merci les gens!
# ##################### PAGE #####################
#  Salut les gars, J'aimerais savoir qui a reussi  tester le prototype? j'aimerais avoir des retours
# ##################### PAGE #####################
#  <#441274712417632267>
# ##################### PAGE #####################
#  Fait une demande
# ##################### PAGE #####################
#    J'avais fait une demande recemment sur <#373070892391071747> , je peux remettre le post dans <#441274712417632267>  ?
# ##################### PAGE #####################
#  Salut tout le monde, voila une update avec les perso Human cette fois-ci.  Je ne voulais pas les faire trop lourdement equipes comme des soldats, je voulais que ca soit juste des Hommes normaux qui se debrouillent avec du vieux matos. J'avais en tete egalement l'idee de leur couvrir le visage  cause des gazs toxics et des odeurs nauseabondes que peuvent emaner les Zeds et leur environnement.
# ##################### PAGE #####################
#   (sifflement d'admiration )
# ##################### PAGE #####################
#  C'est assez chelou parce que je suis pas fan du style voxel en temps normal mais je trouve que tes persos tout maigres fonctionnent super bien !
# ##################### PAGE #####################
#  T'as un port folio dans lequel on pourrait voir d'autres trucs dans d'autres styles ?
# ##################### PAGE #####################
#  C'est cool ca fait plaisir! Le voxel peut etre tres chouette comme style. Je pense que le truc c'est qu'il y a eu beaucoup de Minecraft-like, et faut dire que le style de minecraft c'est vraiment pas du beau voxel art. Et oui j'ai un portfolio, il est un peu outdated, j'y ai rien poste depuis es mois   Mais bon, ya quand meme pas mal de trucs que j'ai fait :
# ##################### PAGE #####################
#  GG ! Vraiment
# ##################### PAGE #####################
#  Ca fait du bien d'avoir un artiste de plus sur ce discord... On est cerne par les codeurs ^^
# ##################### PAGE #####################
#  Merci! Haha, c'est cool alors! A la base je suis artiste 3D, c'est mon job. Je m suis lance dans UE4 il y a deux ans a cause de son systeme de blueprints que je trouve juste REVOLUTIONNAIRE !   C'est un moyen pour un non codeur comme moi de pouvoir faire des jeux. En tout cas si y a besoin ici, je peux aider et donner des conseils sur tout ce qui est 3D, art etc...
# ##################### PAGE #####################
#  C'est cool ^^ Je suis exactement dans la meme situation que toi. J'etais artiste et grace aux BP, je suis en train de devenir un gamedev complet
# ##################### PAGE #####################
#  C'est super! Je pense que le monde du developpement de jeux video est en train de s'ouvrir grandement sur les artistes!
# ##################### PAGE #####################
#  Y a surtout que maintenant, on peut faire des jeux tout seuls ^^
# ##################### PAGE #####################
#  Bientt, les codeur seront comme les sabotiers : dans des musee
# ##################### PAGE #####################
#  *(je vais me faire allumer ^^)*
# ##################### PAGE #####################
#  BONJOUR!
# ##################### PAGE #####################
#  carrement, mina ^^
# ##################### PAGE #####################
#  Ouais ca permet de developper nos idees independament.  Je pense que tu vas te faire allumer oui hahaha!!   Mais je comprend ce que tu veux dire, mais j'ai quand meme envi de me lancer dans le C++ un de ces jours, malgre que la route a l'air loooooongue
# ##################### PAGE #####################
#  En vrai, si tu maitrise bien le BP, tu retrouve assez vite tes marques en C++. On retrouve tous les nodes qu'on connait dej.
# ##################### PAGE #####################
#  Mais au debut, c'est chaud, c'est vrai aussi
# ##################### PAGE #####################
#  Ca c'est cool. C'est juste la structure et la facon dont le C++ marche qu'il faut surtout comprendre je pense
# ##################### PAGE #####################
#  J'ai eu la chance de commencer dans le web. Du coup, j'ai fait beaucoup de AS2 et de php. C'est pas exactement le meme delire mais ca m'a rassurer d'avoir ca dans mes bagages
# ##################### PAGE #####################
#  (J'ai surotut eu la chance d'arreter de faire du web, hein ^^)
# ##################### PAGE #####################
#  Aller, j'arrete de polluer ton chan et je me remets au boulot ^^
# ##################### PAGE #####################
#  Haha, courage!   j'y retourne aussi
# ##################### PAGE #####################
#   bien le bonjour du sabotiers!
# ##################### PAGE #####################
#  non mais ho!
# ##################### PAGE #####################
#  Je te verrais bien dans un petit film en noir et blanc qui explique de maniere pedaggique aux enfants en quoi consistait ton metier ^^
# ##################### PAGE #####################
#  A cote de l'expo de lance de chasseur de baleine.
# ##################### PAGE #####################
#  on se voit au musee quand le robot deviendront artiste avec l'IA
# ##################### PAGE #####################
#  C'est ca qui est cool. Ca n'arrivera jamais
# ##################### PAGE #####################
#  mefiez vous quand meme :
# ##################### PAGE #####################
#  Bluffant !
# ##################### PAGE #####################
#  Mais ca n'invente rien ^^
# ##################### PAGE #####################
#  le code aussi on disant ca
# ##################### PAGE #####################
#  maintenant le code, "se code"
# ##################### PAGE #####################
#  Aller, je me mets en rouge, j'ai trop de taf pour deconner ^^
# ##################### PAGE #####################
#  Salu les gars, j'ai commence  bosser sur l'environement aujourd'hui. Je commence par tout ce qui est sol : plaines, routes, trottoirs etc... J'experimente quelques looks, mais j'ai en tete le contraste aride / humide, comme un lendemain pluvieux dans une plaine aride, ou un marais humide qui aurait seche.  Partagez vos pensees
# ##################### PAGE #####################
#  (J'ai pas pu poster le gif directement, jsuis dans lbus  )
# ##################### PAGE #####################
#  lol !
# ##################### PAGE #####################
#  GG encore !
# ##################### PAGE #####################
#  Tu me reconcilie avec le voxel
# ##################### PAGE #####################
#  Haha! Cool alors ca fait plaisir d'entendre ca!
# ##################### PAGE #####################
#  woaa tu bosse bien
# ##################### PAGE #####################
#  Hey merci! ;)
# ##################### PAGE #####################
#  #screenshotsaturday
# ##################### PAGE #####################
#  Je continue de produire des props pour l'environment. La semaine prochaine je commence  les exporter pour 3ds et preparer les assets pour UE4
# ##################### PAGE #####################
#  Aujourd'hui je bosse sur les Panneaux Neons qui seront les principales sources de lumiere dans le jeu.  Voila  quoi ressemblerais un Dunkin' Donuts pour Zombie
# ##################### PAGE #####################
#  cool
# ##################### PAGE #####################
#  Je pense qu'on devine un certain talent
# ##################### PAGE #####################
#  Il est tres classe
# ##################### PAGE #####################
#  Archi style ! j'aime beaucoup le cote neon
# ##################### PAGE #####################
#  Hey merci les gars! J'apprecie votre support!  Il y en aura d'autres  venir
# ##################### PAGE #####################
#  super rendu
# ##################### PAGE #####################
#  et vraiment fun surtout
# ##################### PAGE #####################
#  Vraiment enorme ! GG
# ##################### PAGE #####################
#  pffff c'est navrant
# ##################### PAGE #####################
#  (de voir commenttu bosses bien et rapidement  )
# ##################### PAGE #####################
#  Mais... C'est de toute beaute
# ##################### PAGE #####################
#  Tu vas utiliser l'emissive dans des lumiere prerendue ou tu planque des source dynamiques derriere chaque neon ?
# ##################### PAGE #####################
#  Je pense qu'avec le nouveau systeme de rendu volumetrique de la lumiere,, tu peux vraiment tenter l'emissive toute seule... Faut voir le resultat sur tes persos mais ca m'interesse
# ##################### PAGE #####################
#  Merci les gars! Ca motive d'entendre tout ca    je pense que je vais utiliser que de l'emissive et une lumiere en stationary. Je compte tout baker pour mes environments. Le resultat sera plus beau et beaucoup moins couteux.  Mais oui, j'ai pas du tout teste le nouveau systeme de rendu volumetrique du tout, je serais curieux de savoir comment ca marche, quelqu'un a des tutos la dessus plz?
# ##################### PAGE #####################
#  Pas de tutos precis mais il me semble que t'as rien de special  faire. quand tu bake tes light, il place les petit volume dans l'espace automatiquement.
# ##################### PAGE #####################
#  Faut que tu sois en 4.18 ou 4.19, par contre... je sais plus lequel des deux.
# ##################### PAGE #####################
#  Le rendu volumetrique est activer par defaut depuis la 4.18
# ##################### PAGE #####################
#  Tu as juste  regler les parametres de lightmass dans ta scene comme il faut pour avoir un bon rendu de qualite et  build en production
# ##################### PAGE #####################
#  Propre, tu l'anime sur quoi?
# ##################### PAGE #####################
#   Ah d'accord, cool alors!    Je l'ai anime avec screentogif, un petit soft genial qui permet de faire des capture d'ecran et de les enregistrer en gif, mais aussi d'en creer / editer.
# ##################### PAGE #####################
#  Pas le gif, l'animation du model
# ##################### PAGE #####################
#   le modele est pas anime en fait, c'est plusieurs rendus avec certains panneaux eclaire et d'autres non que j'ai tout simplement mi l'um derriere l'autre dans screentogif. Un peu comme on l'aurais fait avec after
# ##################### PAGE #####################
#  Pour l'instant !
# ##################### PAGE #####################
#  Oui pour l'instant c'est vrai. Ensuite j'animerais un scalar pafameter dans ue4
# ##################### PAGE #####################
#  Alors moi j'ai une question, on va jouer le zombie ou le survivant ?
# ##################### PAGE #####################
#  Si il fait comme dans le premier, on sera un zombie
# ##################### PAGE #####################
#  Il me semble qu'on joue une bande de zombie qui ont de plus en plus faim et qui doivent bouffer des humains pour que le jeu continue...
# ##################### PAGE #####################
#  Le 1 etait genial, le seul soucis est la duree de jeu
# ##################### PAGE #####################
#  Yes, on joue les Zombies, Apres le systeme de faim comme dans le prototype sera un peu revise. Ce sera surtout une prise de territoire. Dans le monde dans lequel le jeu se deroule, les Zombies ont reussi  envahir le monde et ont commences  developper leur communaute avec leurs villes, leurs magasins, ils ont egalement reduit les humains en esclavage pour se nourrir tranquillement (d'ou le fait que le systeme de faim va disparaitre).  Un jour les Humains se revoltent et le jeu commence. Ils prennent les territoires Zombies et le joueur doit les recuperer (Un peu comme San Andreas).  Le premier jeu etait fait pour une Game Jam donc j'avais pas vraiment eu beaucoup de temps pour developper le gameplay et le faire durer. 1heure de manger dans les poubelles aurait vite souler n'importe quel joueur   . Mais comme l'idee et l'art style a ete tres apprecie c'est pour ca que je continue avec un jeu beaucoup plus riche, ca me permet en meme temps de developper mn univers.
# ##################### PAGE #####################
#  Dans ce cas je suis presse de voir ca !
# ##################### PAGE #####################
#  Voila un autre petit panneau lumineux qui ferra office de light dans un des levels du jeu.  le ''Coff Inn Motel'' (Coffin = Cercueil en anglais)
# ##################### PAGE #####################
#  je me demande ce qu'ils servent au p'tit dej
# ##################### PAGE #####################
#  a toi d'imaginer ...
# ##################### PAGE #####################
#  oeil au plat bacon d'arriere-train
# ##################### PAGE #####################
#  miam
# ##################### PAGE #####################
#  il au plat
# ##################### PAGE #####################
#     gg l'oeil au plat!!
# ##################### PAGE #####################
#  vendu par deux..  et pour 1$ de plus, un de chaque couleur
# ##################### PAGE #####################
#   tu peut laisser le nom en Coff Inn, Inn signifiant deja Motel, Auberge
# ##################### PAGE #####################
#  Sinon GG, j'aime beaucoup ton travail en voxel
# ##################### PAGE #####################
#    Yes c'est justement ca l'idee, c'est vrai que Coff Inn suffit, au lieu de Coff Inn motel. Je pourrais essayer sans le "Motel" en haut et voir.  En tout cas merci
# ##################### PAGE #####################
#  Comment a tu fait pour mettre ses effet de lumiere ?
# ##################### PAGE #####################
#   Emmisive, je pense
# ##################### PAGE #####################
#  Si tu parles de ce genre d'effet c'est emmissive
# ##################### PAGE #####################
#  Yes c'est de l'emissive couplee avec du bloom/glow pour que ca "brille". Autrement, l'emissive seule ne fait pas cet effet de halo autour s'il n'y a pas de bloom d'active, ou alors ca le fait mais pas tellement. La je parle de Magicavoxel biensur. Apres suivant les softs ca peut differer.
# ##################### PAGE #####################
#  Nouveaux post sur le devlog  propos de la production d'assets, du graphisme en general. Si vous voulez faire un tour, voici le lien  :
# ##################### PAGE #####################
#  J'ai pas eu beaucoup de temps pour Embuscade 2 ces derniers jour car je bosse sur un projet client. Mais j'essaie de produire des assets regulierement
# ##################### PAGE #####################
#  Salut les gens, cette semaine c'est animation de personnage! J'utilise mixamo pour ceux qui veulent savoir, c'est un petit bijoux d'animation qu'adobe nous offre gratuitement. Pour ceux qui ne connaissent pas (J'en doute fort) voila le lien :
# ##################### PAGE #####################
#  Yes... Plusieurs personne ici trouve ca pas terrible  mixamo.
# ##################### PAGE #####################
#  Donc comme quoi.
# ##################### PAGE #####################
#   : En fait, ce que l'on reproche le plus souvent  Mixamo, c'est qu'il va rigger automatiquement un  perso pour pouvoir lui appliquer des anims tiree d'une sorte de bibliotheque d'anim. Ca marche tres bien avec des humanodes et tant que tu n'as pas besoin d'une anim particuliere qui ne serait pas dans la bibliotheque. L'avantage, c'est exactement le probleme : En utilisant mixamo, tu n'aprends pas  rigger et  animer. Du coup, des que tu sors des clous de ce que mixamo permet, tu es coince. Dans certain cas, c'est parfait mais c'est vrai que j'ai tendance  deconseiller Mixamo aux debutants parce que c'est un gros shortcut et que le jour o tu veux faire un chien ou un martien, t'es foutu.
# ##################### PAGE #####################
#  Je voulais juste dire quil avait reussi  en faire quelque chose. Je ne parlais pas spicialement de toi.
# ##################### PAGE #####################
#  Tkt ^^ Je voulais juste rappeller les avantage *et les inconvenient* de Mixamo, c'est tout
# ##################### PAGE #####################
#     Exact, mixamo est un shortcut, ca n'apprend pas le rig  celui qui l'utilise Merci de preciser  . Par contre il ne faut pas se priver de ce genre d'outil car on sait tous que le developpement prend enormement de temps et si on commence  tout vouloir faire from scratch, on en a pour des annees. Si un debutant qui ne connait rien en rig a besoin d'un personnage humain rigge et anime simplement, donc courrir, marcher, sauter, mourir, Idle; Mixamo lui sera d'une excellente utilite, il trouvera tout ce qu'il voudra et meme plus!  Et il perdra moins de temps  bouger un peu les bones de son rig pur customiser son anim nqu'a apprendre a rigger depuis la base.  Par contre, il est quand meme important pour un debutant qui veut utiliser Mixamo de connaitre des bases en modelisation de personnage pour l'animation. Par exemple ou mettre les edges pour que les articulations se plient bien. Sur youtube il y a plein de video tutorial a ce propos. Et si un jour ce debutant veut rigger un animal, eh bien il y sera confronte  un challenge de plus dans sa vie de developpeur inde
# ##################### PAGE #####################
#  On est tout  fait d'accord
# ##################### PAGE #####################
#  Une petite annonce pour tous ceux qui suivent le jeu, Embuscade 2 va changer de titre bientt, j'avais precise sur le devlog que le titre etait provisoire. Je souhaite le changer pour quelque chose de plus parlant. Et aussi pour respecter le premier jeu qui avait un assez gros sens narratif, j'aimerais que le second jeu, qui est plus oriente gameplay, se detache du precedent.  Pour ceux qui ont des idees n'hesitez pas!
# ##################### PAGE #####################
#  Ha tu cherche un titre !
# ##################### PAGE #####################
#  Famine
# ##################### PAGE #####################
#  Starvation
# ##################### PAGE #####################
#  Hunger *not a* game
# ##################### PAGE #####################
#  Crowd
# ##################### PAGE #####################
#  Band of broZers
# ##################### PAGE #####################
#  The horde
# ##################### PAGE #####################
#  Z swarm
# ##################### PAGE #####################
#  Comment j'ai mange mon pere (*je crois que ca existe dej ^^)*
# ##################### PAGE #####################
#  Fucked Up Zombies
# ##################### PAGE #####################
#  Z engine
# ##################### PAGE #####################
#  Giselle project
# ##################### PAGE #####################
#  Yumi cortex
# ##################### PAGE #####################
#  Gnnnnnaaaaaa
# ##################### PAGE #####################
#  La tete dans le cul
# ##################### PAGE #####################
#  Journee de merde
# ##################### PAGE #####################
#  De l'echec des politiques liberales
# ##################### PAGE #####################
#  BrainStorming
# ##################### PAGE #####################
#  Pourquoi la drogue, c'est mal.
# ##################### PAGE #####################
#  y a des noms cool l-dedans, famine ou starvation (pour les anglophones) j'aime particulierement. le Fuck Up Zombies x), le Giselle Project XD.
# ##################### PAGE #####################
#      merci pour les idees. ca tourne pas mal autour de la faim ouais
# ##################### PAGE #####################
#  apres tu comptes implementer quoi comme gameplay?
# ##################### PAGE #####################
#  genre c'est quoi ton pilier principal
# ##################### PAGE #####################
#  parce que Jogo a assume que c'etait la survie de zombie, donc miam miam, mais autant tu vas changer
# ##################### PAGE #####################
#  Brain Dead
# ##################### PAGE #####################
#  J'ai vue un petit "Giselle project" se glisser dans la liste de JoGoiA
# ##################### PAGE #####################
#  Dans un monte ou les Zombies ont pris le controle sur la race humaine, le joueur controle une horde de Zeds qu'il dirige directement avec le joystick. Les humains qui ont survecu essaient de reprendre leur territoire.  C'est un style de gameplay un peu comme right click to necromance ou le joueur peut infecter les humains pour qu'ils mutent en Zombies et rejoignent sa horde, mele  du GTA SA dans la guerre des gangs pour les prises de territoires
# ##################### PAGE #####################
#  Venez voter pour le nouveau titre de Embuscade 2 sur twitter, j'ai besoin de vous les amis
# ##################### PAGE #####################
#  C'est 3 variable du meme nom
# ##################### PAGE #####################
#  Rooh, mon compte twitter a ete suspendu, joeux pas voter
# ##################### PAGE #####################
#    oui, j'ai dej fait mon choix  90% mais j'hesite encore sur les derniers details du titre
# ##################### PAGE #####################
#    compte twitter suspendu? Wow pourquoi?
# ##################### PAGE #####################
#  J'ai pas l'ge necessaire
# ##################### PAGE #####################
#  Enfin, j'ai maintenant l'ge necessaire, mais il me l'ont cloture 2-3j juste avt mon aniversaire
# ##################### PAGE #####################
#  Et pr le debloque, jdois donner une copie d'une piece d'identite, non mais oh
# ##################### PAGE #####################
#  Oh les salaud!   Ils sont serieux? Je savais meme pas qu'il y avait un age minimal pour twitter. Quand je vois que des gens de 7 ou 8 ans ont FB je pensait que tout etait permis   Je veux heurter personne ici biensure
# ##################### PAGE #####################
#  Bah mtn, avec la nouvelle loi sur la recolte de donnees personelles, twitter a commencer a transpirer, et a fermer tt les comptes de gens de -16ans
# ##################### PAGE #####################
#  Et avt c'etait "interdit" d'avoir un compte sur n'importe quel reseau social si t'as pas 13ans
# ##################### PAGE #####################
#  J'ai vote mais honnetement, je trouve que toutes tes propositions sont vraiment un peu convenues... Entre les ZZZZ et le brain... tu sors vraiment pas du tout des sentiers battus et rien qu'en terme de referencement sur google, tu vas etre noye dans la masse.
# ##################### PAGE #####################
#  Je serais toi, je continuerais de chercher un peu
# ##################### PAGE #####################
#   hey merci! C'est vrai que les sentiers sont deja battus, mais apres quelques temps passe sur google a rechercher, jetais etonne de voir qu'il n'y a pas tant de resultat que ca. En cherchant brainzzzz jai un peu plus de resultats mais pas enormement. En cherchant no brainerzzzz j'en ai presque pas, google enleve tous les zzzz. Aors je pensait qu'il y a peut etre une petite place ici. Mais je me trompe peut etre. J'aimais l'idee des zzzzz pour faire reference au nombre, a la masse de zombies dans oe jeu.
# ##################### PAGE #####################
#   ah cest vrai? Je savais pas ca!
# ##################### PAGE #####################
#  Voila les 3 titres que j'avais propose sur twitter : (pour ceux qui n'ont pas twitter comme  ) 1. Brainzzzzz - 2. Brainerzzzzz - 3 No Brainerzzzzz Personne ne semble aimer ces noms, comme quoi, vaut mieux demander avant   "J'aime aucun" , "Trop convenues", "On dirait une faute tous les ZZZZ" , "Les zombies mangent pas forcement les cerveaux" , etc... Pour ceux qui veulent quand meme voter pour l'un d'eux cliquez sur le petit chiffre de votre choix.   Du coup, j'ai continue  penser un peu, un nom m'est venu en tete, 4. "Zed Zone" Qu'en pensez vous? Votez 4 pour lui
# ##################### PAGE #####################
#  Je propose un autre nom  5.DeadlyHorde
# ##################### PAGE #####################
#  Les ZZZZ, ca fait aussi le mec qui dort en BD ^^
# ##################### PAGE #####################
#  Dead Cell, le mot "Cell" aillant une double signification coulant toutes 2  ton jeu.
# ##################### PAGE #####################
#  Dej pris? arf
# ##################### PAGE #####################
#  ^^
# ##################### PAGE #####################
#  Putain et c'est en + un jeu de zombie aussi xD
# ##################### PAGE #####################
#  Franchement, je crois que trouver un titre original pour un jeu avec des zombis est un petit defi aujourd'hui ^^
# ##################### PAGE #####################
#  Vu comment le concept a ete suce jusqu' la moelle, c'est pas etonnant non plus :/
# ##################### PAGE #####################
#  C'est pour ca que pour moi, il faut trouver une solution qui dit "on est dans un truc tres fait mais on a notre truc  nous". Un titre qui permette de donner une identite propre tout de suite pour eviter d'etre un jeu de zombi de plus.
# ##################### PAGE #####################
#  Je pense que l'identite du jeu repoe sur le fait de controller une horde au lieu de buter du zombie a coup de riffle comme dans tout ce qui se fait sur le marche. Du coup ca serait pas mal de mettre ca en avant?
# ##################### PAGE #####################
#  Et y a une donnee qu'on a pas max, c'est le ton de ton jeu. C'est un truc rigolo avec des zombis debiles ou c'est un truc un peu horreur avec des zombi au premier degre et des humains dans la merde ?
# ##################### PAGE #####################
#  Brain, Z tout ca, ca rammene au zombi cartoon.
# ##################### PAGE #####################
#  Okay donc raison de plus pour ne pas choisir ce theme. Je suis plutot dans un ton d'horreur, un peu comme le premier jeu. Avec des zombies "smart" et des humains dans la merde
# ##################### PAGE #####################
#  Le controle de horde en mode serious business, t'as Plague Inc qui la fait, un bon jeu d'ailleurs
# ##################### PAGE #####################
#  C'est bien ce qui me semblait ^^
# ##################### PAGE #####################
#    yes j'ai vu ca, ca a l'air cool! Mais je suis pas dans ce style de jeu de gestion. Le mien c'est un jeu d'action. de mele
# ##################### PAGE #####################
#  Du coup, tu peux chercher du cote de la contagion, de la peste...*
# ##################### PAGE #####################
#  Un truc qui se repand...
# ##################### PAGE #####################
#  Un truc genre "flat line", ca evoque l'encephalogramme plat des zombie, la maladie....
# ##################### PAGE #####################
#  ouais ouais j'avais note des mots cle faisant reference  la contagion, la multiplcation, un truc qui se repand exponentiellement
# ##################### PAGE #####################
#  Bip bip Biiiiiiiiiiiiiiiiiiiiiiiip
# ##################### PAGE #####################
#  Ah je vois, ca evoque oui.
# ##################### PAGE #####################
#  Apres, y a tout le domaine de la horde....
# ##################### PAGE #####################
#  swarm, horde, pack, crowd...
# ##################### PAGE #####################
#  Horde ca parle de soit c'est bien, on sait directement que c'est des Zeds quoi. mais c'est peut etre a double tranchant
# ##################### PAGE #####################
#  le meute
# ##################### PAGE #####################
#  Surtout, t'as dej un film de zombi qui s'appelle "la horde"
# ##################### PAGE #####################
#  (tres bien et francais, d'ailleurs !)
# ##################### PAGE #####################
#  connu?
# ##################### PAGE #####################
#  Assez ^
# ##################### PAGE #####################
#  Ah ouais? cool, je vais regarder un trailer
# ##################### PAGE #####################
#  Je peux ajouter un sous titre aussi pour preciser
# ##################### PAGE #####################
#  Tu pourrais aussi jouer sur un truc du lore de ton jeu... Si l'epidemie est du  un produit chimique par exemple, tu appelle ton jeu C4 H12 O2 et dans le jeu, on a des baril de produit chimique qu'on fait peter pour contaminer tout une zone...
# ##################### PAGE #####################
#  Ou "bifidus actif" si c'est une epidemie liee aux yaourts...
# ##################### PAGE #####################
#  Ou "the cult" si tout part d'une secte de magicien noir...
# ##################### PAGE #####################
#  The cult, si tu le justifie par le lore, c'est pas mal parce que il y aussi l'idee de groupe
# ##################### PAGE #####################
#  Mais ca fait plus magie noire...
# ##################### PAGE #####################
#  Ou alors, tu trouve ta propre facon de nommer les zombies.
# ##################### PAGE #####################
#  Dans walking dead, chaque groupe de survivant a sa propre facon de parler de zombis sans jamais dire le mot zombis: walkers, runner, musher, rampant...
# ##################### PAGE #####################
#  C'est vrai ouais, je suis pas dans ce theme en fait.Malgre que l'idee est cool! Hmm ca aussi c'est pas mal. Des mots qui evoque le terme Zombie...
# ##################### PAGE #####################
#  machouilleurs, chewer, tremblotants, dodelinant, lent...
# ##################### PAGE #####################
#  Tu les appelle dej les zheds, non ?
# ##################### PAGE #####################
#  Ouais, sans le H, Zeds, mais peut etre que je peux y songer  le rajouter.  C'etait pour ca que j'avais pense  Brainer et No Brainer au debut. Pour appeler un Zombie d'une autre maniere
# ##################### PAGE #####################
#  Ouais mais tu retombe dans le "brain" du coup...
# ##################### PAGE #####################
#  Et brain, c'est vraiment ce que dis un zombi dans un dessin anime.
# ##################### PAGE #####################
#  Ah ouais d'accord. Ca fait reference  un Zombie debile quoi XD
# ##################### PAGE #####################
#  Il est vraiment degueu ce zombi ^^
# ##################### PAGE #####################
#  Ah ouais atroce! XD
# ##################### PAGE #####################
#  Aller ! Je te laisse cogiter
# ##################### PAGE #####################
#  merci beaucoup en tout cas!
# ##################### PAGE #####################
#  Avec plaisir
# ##################### PAGE #####################
#  The SnackMen
# ##################### PAGE #####################
#  "Eating brain is not that bad."
# ##################### PAGE #####################
#  Bon nom pour un jeux Inde x)
# ##################### PAGE #####################
#    C'est vrai que c'est pas mal comme nom.   ca fait sourrire, peut etre un petit peu trop. Je compte quand meme avoir un brin d'humour dans mon jeu, un peu comme dans Zombie night terror pour ceux qui connaissent. Mais j'ai peur qu'un titre comme ca ne fasse pas assez serieux.    I think this doesn't tell enough about the game
# ##################### PAGE #####################
#  Gofa,  cote de la plaque qui se lance des fleur tout seul
# ##################### PAGE #####################
#  Eh, les nom long sont pas forcement mauvais hein
# ##################### PAGE #####################
#  Je suis tres pour ! on parlait de retirer brain du titre, en fait ^^
# ##################### PAGE #####################
#  Desole pour l'anglais, je bosse pour un client en ce moment, ca m'a formate la tete
# ##################### PAGE #####################
#  tkt ^^
# ##################### PAGE #####################
#  Kurlrip arrivera  suivre ^^
# ##################### PAGE #####################
#  World of knackie
# ##################### PAGE #####################
#  owi
# ##################### PAGE #####################
#  proces !
# ##################### PAGE #####################
#  mais non ca leur fait de la pub. ...
# ##################### PAGE #####################
#  no knackie avec des vrai bout de gens dedabns
# ##################### PAGE #####################
#  et ca rime
# ##################### PAGE #####################
#  Les bonne saussices  base d'humain ^^
# ##################### PAGE #####################
#  Dej qu'on sait pas trop ce qu'il y a dedans...
# ##################### PAGE #####################
#  "Hier j'ai manger quelqu'un"
# ##################### PAGE #####################
#  J'avais propose "comment j'ai mange mon pere", hier ^^
# ##################### PAGE #####################
#  "Demain je mangerais quelqu'un" ?
# ##################### PAGE #####################
#  Ca aurait ete cool pour un jeu du genre walkthrough racontant comment un gars s'est transforme en Zombie
# ##################### PAGE #####################
#  Y a une reference litteraire et tout ^^
# ##################### PAGE #####################
#  'huumm who's this ?"
# ##################### PAGE #####################
#  desole ca me fait marre de trouver des truc con
# ##################### PAGE #####################
#  Super meta, kurl ^^
# ##################### PAGE #####################
#  "Zombie Express"
# ##################### PAGE #####################
#  ou "hummm who does it smell"
# ##################### PAGE #####################
#  "J'irais manger chez vous"
# ##################### PAGE #####################
#  "Au repas ; Vous"
# ##################### PAGE #####################
#  C'est drle de trouver des nom pour du inde putain xD
# ##################### PAGE #####################
#  C'est chelou ton idee de titre pour "jeu inde"...
# ##################### PAGE #####################
#  Un diner presque parfait !
# ##################### PAGE #####################
#  Proces !
# ##################### PAGE #####################
#  "Vous, mais avec des epices"
# ##################### PAGE #####################
#  "Un Zombie presque parfait !" ?
# ##################### PAGE #####################
#  J'ai eu l'idee de peut etre inclure la marque du pluriel, pour evoquer le nombre mais aussi de quel cote le joueur se trouve. genre "They are billions" ca serait "We are billions". Juste pour exemple.
# ##################### PAGE #####################
#  "Votre cerveaux s'il vous plait."
# ##################### PAGE #####################
#  "Pourriront-nous manger votre cerveaux ?"
# ##################### PAGE #####################
#  Bon aller, je continue mon anime xD
# ##################### PAGE #####################
#  Hahah! Tu m'as fait bien marre en tout cas!
# ##################### PAGE #####################
#  "Boiled head"
# ##################### PAGE #####################
#  ou "Boiled brain"
# ##################### PAGE #####################
#  Zed alert
# ##################### PAGE #####################
#  pas mal
# ##################### PAGE #####################
#  Un p'tit clin d'il
# ##################### PAGE #####################
#  Franchement, j'aime bien celui-l ^^
# ##################### PAGE #####################
#  Pour info, depuis que je suis le twitter de Max, j'ai plein de super screen que vous n'avez pas, nananere
# ##################### PAGE #####################
#  putain ca a trop de la gueule ce qu'il (tu) fait !!!
# ##################### PAGE #####################
#  Brain's Out
# ##################### PAGE #####################
#  Salut les gars, Merci pour la motivation que vous me donnez encore une fois!    Et merci   de partager mon twitter ca fait plaiz   Et oui, je poste tous les jours sur twitter aux alentours de 23h donc pour ceux qui veulent suivre le deveoppement du jeu de plus pres venez nous rejoindre!  Sinon ya aussi le devlog pour ceux qui n'ont pas twitter, j'y poste tous les mardi avec plus de contenu, mais je suis en train de songer  poster plus souvent, peut etre deux fois par semaine  partir de la semaine prochaine.  Voil le lien >>>  Et autre annonce, je vais bientt migrer mon devlog vers un autre site plus personnalise, je vous tiendrais au courant de toute facon
# ##################### PAGE #####################
#  Et maintenant Les Zombies sont enfin dans UE4! On va bientot pouvoir faire joujou
# ##################### PAGE #####################
#  J'ai vu ton derneir twit, max, celui d'apres celui l.
# ##################### PAGE #####################
#  Je trouve que tes perso glissent un peu au sol quand ils marchent.
# ##################### PAGE #####################
#  Tu devrais check la vitesse de tes anims pour eviter ca
# ##################### PAGE #####################
#  Sinon, j'arrive pas encore  vor le gameplay... On  clic par terre pour faire bouger les zeds ?
# ##################### PAGE #####################
#  Ou on les dirige  la manette ?
# ##################### PAGE #####################
#  Je vois que tu as des petit terrain carre, tu vas en assembler plusieurs pour fabriquer des levels proceduraux ?
# ##################### PAGE #####################
#    Hey salut!   Yes ils glissent pour le moment, c'est la premiere pass d'anim, je compte biensur ameliorer tout ca par la suite. Pour le moment je me focus sur faire mon premier niveau + HUD pour la semaine prochaine. Faire ressembler le tout  un vrai jeu. C'est un gros challenge vu que j'ai un job  cote, mais quand il faut y aller faut y aller.   Et en fait le joueur dirige les Zeds directement avec le joystick, comme si c'etait un seul personnage. Et pour la map je sais pas si je vais faire des levels proceduraux. J'aime bien travailler mes levels pour qu'ils soient artistiquement interessant et  la fois designe pour le gameplay. Du coup j'aime bien les faire un par un malgre le temps que ca prend. Mais ca reste encore  decider.
# ##################### PAGE #####################
#  En tout cas, j'adore l'ambiance un peu brumeuse et franchement tu avance bien !
# ##################### PAGE #####################
#  GG
# ##################### PAGE #####################
#  Cool, j'suis content que t'aimes bien, Merci! Ca motive!
# ##################### PAGE #####################
#  Tu me motive aussi, tu sais
# ##################### PAGE #####################
#  C'est bien de voir des projet qu avancent ^^
# ##################### PAGE #####################
#  Ah content d'entendre ca! Tu bosses sur quoi toi?
# ##################### PAGE #####################
#  <#373071538846695435>
# ##################### PAGE #####################
#  Ah oui je m'en souviens maintenant! ;) Je me rappel d'un rig de martien robot a 3 pattes que t'avais fait, je me trompe?
# ##################### PAGE #####################
#  Exactement ^^
# ##################### PAGE #####################
#  Hello les gens, apres avoir pas poste depuis un ptit moment, voila du nouveau avec ce Set de UI elements. J'ai du revoir pas mal de choses au niveau des design pillars du jeu, j'ai ete vite dans la creation d'assets etc, mais il me manquait pas mal de concept a mettre a plat avant de continuer, d'o le temps d'attente.
# ##################### PAGE #####################
#  Je suis pas sr sr des bouton qui saignent quand on les survole ^^ C'est tres "mortal kombat", remarque
# ##################### PAGE #####################
#  Hey salut,   pourquoi tu pense que ca peu ne pas aller les boutons qui saignent?
# ##################### PAGE #####################
#  ben ca fait ado quoi....
# ##################### PAGE #####################
#  des bouton qui saignent
# ##################### PAGE #####################
#  ok je sort.....
# ##################### PAGE #####################
#  Je dis pas que c'est pas possible, hein ^^ Les boutons qui saignent, c'est retro, on va dire... Rien de nul ou de choquant
# ##################### PAGE #####################
#  Ah oui je vois! Alors c'est parfait, j'aimerai bien donner un cote retro aux UI   En fait je veux m'eloigner des UI sci fi present dans tous les jeux ou presque. Si c'est un jeu Sci fi ca colle, mais je trouve que parfois c'est utilise sans raison.
# ##################### PAGE #####################
#  Tu as raison !
# ##################### PAGE #####################
#  Et meme dans la SF, il y aurait moyen d'avoir un peu d'imagination
# ##################### PAGE #####################
#  Je dis ca et en meme temps, je vais srement pas etre tres original dans mon UI.... En meme temps, il faut d'abord viser la clarte
# ##################### PAGE #####################
#  Ouais c'est sur, Les joueurs prefereront un UI clair en priorite  un UI tres original!
# ##################### PAGE #####################
#  LUT setting Black and White avec filtre Rouge pour l'etat de frenesie des Zombies.
# ##################### PAGE #####################
#  Pour ceux qui aimerais l'utiliser je vous donne le PNG, j'espere que ca servira  certains
# ##################### PAGE #####################
#  Ca va passer en PNG ?
# ##################### PAGE #####################
#  Remarque.. c'est pas compresse...
# ##################### PAGE #####################
#  Merci
# ##################### PAGE #####################
#  Yes ca devrait passer, faut juste enlever les MipMaps et mettre le texture group en "ColorLookupTable" pour enlever la compression
# ##################### PAGE #####################
#  Non mais oui ^^
# ##################### PAGE #####################
#  En JPEG, ca passe pas par contre ^^
# ##################### PAGE #####################
#  Hm non je pense pas non plus! Le mieux c'est peut etre en TGA mais au vu du resultat PNG c'est suffisant normalement
# ##################### PAGE #####################
#  Le probleme, c'est que si tu compress ton LUT, tu vas avoir des artefact, des simplification de couleur... il sera moins precis et si un artefact vient se mettre au mauvais endroit, tu risque meme d'avoir des resultats chelous... D'habitude, on les fais en TGA ou en BMP... Mais il me semble que le format png est non destructif...
# ##################### PAGE #####################
#  Apres, il faut voir aussi si un TGA  pas plus de bit pour definir les couleurs, ca rendrait tes LUT plus precis.
# ...
# ##################### PAGE #####################
#  HeHe ! Je suis super content que tu sois de retour
# ##################### PAGE #####################
#  Vivent les petits zombis
# ##################### PAGE #####################
#  Coooolll
# ##################### PAGE #####################
#  tu nous mets la hype en nous la
# ##################### PAGE #####################
#  Ca fait un mois qu'il nous a pas hype, lisko ^^
# ##################### PAGE #####################
#  D'ailleurs, ca nous manque
# ##################### PAGE #####################
#  ca  l'air vraiment tres tres propre niveau graphisme
# ##################### PAGE #####################
#  faut que j'essaye le voxel en vrais
# ##################### PAGE #####################
#  Des nouvelles ?
# ##################### PAGE #####################
#  Salut les gens! Des nouvelles en effet oui.  Avec mon taff j'ai pas beaucoup de temps pour publier des trucs, ni pour avancer grandement sur No Brainerz  Ca fait deja un bout de temps que je suis sur ce projet maintenant, peut etre 6 oi 7 mois. Il est temps de le finir, la sortie etant en plus prevue pour halloweem alors plus le choix!  Je me rend compte que pas mal de features que je souhaitais voir apparaitre dans le jeu ne pourront fonalement pas etre presentes, mais au lieu d'abamdonner le projet je compte faire une journee  "finish it or delete it".  Pour ceux qui connaissent Game Dev Underground (Tim Ruswick), c'est de l dont vient le concept. Quand un jeu traine a finir et qu'on a envi de pasaer a autre chose, on le finit ou on le supprime! C'est un challenge que j'aimerai relever pour finir No Brainerz dans les temps et pouvoir le publier.
# ##################### PAGE #####################
#  Ca serait cool aussi de le faire durant un live stream mais je crois pas avoir une assez bonne comnexion pour ca, je verrais bien
# ##################### PAGE #####################
#  1 jour ?
# ##################### PAGE #####################
#  Pose une semaine de vacance et donne lui une vraie chance, j'aime bien tes petits zombis
# ##################### PAGE #####################
#  Au pire recrute des gens
# ##################### PAGE #####################
#  J'aimerai bien passer un peu plus de temps dessus, mais je peut pas c'est ca le truc :/ Recruter pourquoi pas, c'est vrai que  j'y avait pas pense.
# ##################### PAGE #####################
#  Des gens qui dev de temps en temps ferais avancer ton projet
# ##################### PAGE #####################
#  Et peut etre meme ajouter de nouvelles idees
# ##################### PAGE #####################
#  Mouais...
# ##################### PAGE #####################
#  Parfois, un petit projet termine vaut mieux qu'un truc qui evolue sans arret et qui restera  jamais inacheve ^^
# ##################### PAGE #####################
#  Bah apres a voir comment le projet a avancer depuis les dernieres fois
# ##################### PAGE #####################
#  Pas de nouvelle de ce projet ?
# ##################### PAGE #####################
#  Il est soit fini, soit  la poubelle ^^
# ##################### PAGE #####################
#  Taggons Max pour le savoir
# ##################### PAGE #####################
#  Oh non pas a la poubelle  C'etait un de mes preferes du serveur
# ##################### PAGE #####################
#  Bah apres avec les cours et tout ca doit etre complique aussi
# ##################### PAGE #####################
#  Salut les gars, c'est vrai j'ai pas fait ce que j'allait dit que j'allait faire    J'ai reconsidere ce que j'avait dit et fait jusqu'a present et je me suis donne un peu plus de temps, rien ne presse. J'ai revisite mon systeme d'IA et j'ai reussi a l'optimiser a plus de 1000%. Normalement le jeu sera capable de supporter 1000 zombies en meme temps sur la map tout en tournant a 60 fps sur une machine comme la mienne (980m, i7 2.2ghz, 16ram).  Donc bonne nouvelle, l'aventure continue  J'aurais peut etre moins souvent de trucs a montrer mais des que j'ai des trucs cool je poste
# ##################### PAGE #####################
#  <@!234336151782162432> veut des zombies nus
# ##################### PAGE #####################
#  HaHa !
# ##################### PAGE #####################
#  J'aime mieux ca
# ##################### PAGE #####################
#  Tu peux expliquer vite fait ce que tu as fait sur les IA ?
# ##################### PAGE #####################
#  1000 IA, ca m'interese  fond !
# ##################### PAGE #####################
#  J'utilise les Hierarchical Instancited static mesh. Par contre du coup faut animer dans le vertex shader et non avec des bones.
# ##################### PAGE #####################
#  Wo putain !
# ##################### PAGE #####################
#  Je vois ce que tu fais ! C'est ruse
# ##################### PAGE #####################
#  Avec des geocache et du alembic, du coup ?
# ##################### PAGE #####################
#  Ou l'anim passe par le world position offset ?
# ##################### PAGE #####################
#  (ca serait super balaise !)
# ##################### PAGE #####################
#  yes l'anim passe par le WPO!
# ##################### PAGE #####################
#  J'avais l'intuition que c'etait possible mais GG pour l'avoir fait !
# ##################### PAGE #####################
#  Nice  ! Un petit gif de ce que ca donne ?
# ##################### PAGE #####################
#  J'avoue :3
# ##################### PAGE #####################
#  Moi, je veux bien voir comment tu fait l'anim ^^
# ##################### PAGE #####################
#  (je reviens dans un moment pour en reparler)
# ##################### PAGE #####################
#  Le material et les texture,quoi ^^
# ##################### PAGE #####################
#  Mais limite, si t'arrives  faire tout ca avec le WPO, tu dois pouvoir en rajouter encore plus  ! T'as teste jusqu' combien t'avais 60 FPS ?
# ##################### PAGE #####################
#  (d'ac !)
# ##################### PAGE #####################
#  du coup, t'as une seule IA pour tout un groupe de zombi ?
# ##################### PAGE #####################
#  Re. Je poste un gif des que possible, la c'est pas encore montrable ^^  Et pour l'anim tu peux la baker avec houdini ou 3ds dans une texture. Ensuite ya un ptit material setup a faire et puis voila! Sur youtube si tu tapes vertex animation tu trouveras facilement, sinon je peux te retrouver le lien
# ##################### PAGE #####################
#  Et oui je peux en theorie en avoir plus, apres ca depend surtout de l'IA des instance. plus c'est compexe et moins je peux en mettre parce que je dois a chaque frame updater le mouvement et le material. Mais en theorie, avec des bons LODs on peut en avoir 10000
# ##################### PAGE #####################
#  Pour l'IA c'est surtout gere avec un IA manager, donc tout le groupe repond au meme maitre, mais ne font pas obligatoirement la meme chose. Apres on peut lancer differentes animations, on peut faire des traces depuis une instance en particulier, tester des collisions sur des instances particulieres, etc... Mais tout est gere par le manager
# ##################### PAGE #####################
#  Des nouvelles de ce projet   ? Jai envie que tu hypes encore plus !
# ##################### PAGE #####################
#  Les bonnes choses prennent du temps
# ##################### PAGE #####################
#  Gnagnagnagna
# ##################### PAGE #####################
#  Toujours rien ? :)
# ##################### PAGE #####################
#  Salut les gens, dej un an sans nouvelles! Le temps passe trop vite...   Avec mon job j'ai pas pu avancer d'un millimetre sur le jeu, non pas parce que j'ai pas le temps de le faire, mais parce que j'ai pas le temps d'apprendre le C++ comme je voudrais pour pouvoir continuer le jeu. Malheureusement certaines choses depassent mes competences en programmation du coup je suis bloque. Donc c'est surement un projet qui sera reprit une fois que je serais plus  l'aise avec le C++. Pour le moment j'ai d'autres projets en vue, avec lesquels je pourrais m'ameliorer et pouvoir enfin reprendre le developpement de No Brainerz.  Je veux surtout pas rusher le jeu, le but etait de faire un jeu o le joueur pouvait controller des milliers de Zombies! Donc il faut des milliers de zombies! Pas des dixaines, pas des centaines, mais vraiment des milliers! Alors ca prendra le temps qu'il faudra, mais  la fin, quand le jeu verra le jour, il y aura des milliers de zombies, comme promis    A propos de mes autres projets je vous tiendrai au courant tres vite (pas dans un an haha   )
# ##################### PAGE #####################
#  Ah bah nice ca . Bonne chance du coup ! ^^
# ##################### PAGE #####################
#  Pour le C++ ouaip, le plus dur est le debut. Hesites pas a passer dans le channel <#391885365016920064> , Apprendre seul sur UE c'est franchement pas evident au debut
# ##################### PAGE #####################
#  Hey, merci!  Je m'y suis mis au C++ ya a peu pres un an  un moment o j'avais du temps pour apprendre. Je trouve que c'etait pas si dur au tout debut en fait, une fois qu'on comprend la syntaxe et le framework en general ca va. Moi ce que j'ai trouve le plus dur c'etait quand je voulais faire des data structure, des algorithmes et tout ca. La j'ai commence  perdre les pedales.
# ##################### PAGE #####################
#  ah ok ^^
# ##################### PAGE #####################
#  Par contre, si tu veux mettre 1000 zombies, ca doit se faire, par contre bonne chance :>
# ##################### PAGE #####################
#  Haha! Merci, j'en aurais besoin! au dessus de 400 - 500 ca commence a devenir vraiment chaud. Mais je pense pas que ca soit impossible, j'ai vu des simulations de flock qui arrivent  des dixaines de milliers! Ya aussi le jeu "they are billions", o il y a enormement de zombie. Ou encore Epic battle simulator, la on a des centaines de milliers de personnages! Donc je garde espoir x)
# ##################### PAGE #####################
#  faut instancier poru faire ca
# ##################### PAGE #####################
#  et UE permet pas d'instancier des skeletal mesh nativement
# ##################### PAGE #####################
#  tu peux utiliser des static mesh avec une animation dansle shaders sinon
# ##################### PAGE #####################
#  mais ouais il va y avoir un sacre defis d'optimisation ^^
# ##################### PAGE #####################
#  Pour qanga on arrive a atteindre les 10k bestiolles qui te ruchent dessus  30 fps sur une grosse machine mais c'est tres basique. Le plus lourd etant l'affichage bien entendu ^^
# ##################### PAGE #####################
#  Yes, je comptais faire des HISM avec des anims dans les shaders, j'avais deja fait quelques tests, tres concluants.  Par contre Je sais pas si c'est vraiment l'affichage, qui posera probleme, pour le moment, afficher 10k HISM posait pas de probleme, tant qu'ils ne bougeaient pas x) C'est en fait la simulation, le calcul des trajectoires et l'update de chacune des instances qui posait probleme. Et biensur, les collisions! La c'etait impensable! Il faut refaire un systeme de collision beaucoup plus simplifie que celui natif d'unreal. C'est pas evident, mais c'est faisable. J'avais fait des tests sur quelques instances et ca marchait pas mal. Mais encore une fois, quand on multiplie les instances, tout deconne ><
# ##################### PAGE #####################
#  oui un autre soucis c'est d'update la position d'un actor Nous ce qu'on fait c'est que cote serveur on deplace pas d'actor / component, on a juste un Objet C++ par IA qui fait des line trace. Aucune physique que dse linetrace. Du coup les 10k ia cote serveur ca passe peinard
# ##################### PAGE #####################
#  du coup en fonction de la distance on update plus ou moins souvent la position de l'ia
# ##################### PAGE #####################
#  et bien sur on l'update que quand elle est visible ^^
# ##################### PAGE #####################
#  Et ces updates cote serveur, ca se fait a chaque frame?
# ##################### PAGE #####################
#  En plus dans qanga la difficulte c'est qu'on replique le tout :p
# ##################### PAGE #####################
#  Bah cote serveur on la bouge pas comme ca probleme regle, on calcule juste la position a partir de line traces ^^
# ##################### PAGE #####################
#  Resultat on peut en mettre une bonne cinquantaine par joueur sans que ca pose un reel probleme de perf ^^
# ##################### PAGE #####################
#  C'est top ca! Du coup ya une cinquantaine visible c'est ca? Mais yen a plus qui sont simules sur le serveur?
# ##################### PAGE #####################
#  ah bah le serveur il simule tout ^^
# ##################### PAGE #####################
#  cinquantaine parce qu'on aura plein d'ia differentes et plein d'autres trucs donc faut que ca bouffe pas trop
# ##################### PAGE #####################
#  mais on peut bien plus oui ^^
# ##################### PAGE #####################
#  Niveau perf les gros trucs lourds dont il faut se debarasser -Calculer la physique -Deplacer un sceneComponent -Envoyer les donnees a tous les clients -Rendre des meshs animes
# ##################### PAGE #####################
#  Pour la physique, t'en fais une maison avec des line trace Pour les deplacement d'un sceneCompoent, bah tu le deplaces pas (ou seulement quand c'est significatif  l'ecran) Pour le multi toi j'imagine que tu t'en fous ^^ Pour les mesh a priori pour toi c'est ok
# ##################### PAGE #####################
#  Merci pour les astuces  Apres moi ce que je voulais faire aussi, c'etait reculer la camera quand le nombre de zombie augmentait pour pouvoir tous les voir xD donc je pense que j'aurais  tous les deplacer, et puis faire des differents level de simulation (des LOD de sim). Plus la camera est eloignee et plus je regroupe certaines instances en une seule qui se deplace sous forme de groupe. Enfin, c'etait une solution a laquelle j'avais pense sans vraiment la tester
# ##################### PAGE #####################
#  ouais, mais plus tu l'eloignes, moins t'es oblige d'update la position souvent ^^
# ##################### PAGE #####################
#  genre quand tu eloignes la cam tu updates la position d'un zolmbie sur 2 de facon random apr exemple
# ##################### PAGE #####################
#  Aah! Bien ca! J'y avait pas pense  C'est vrai que plus c'est loin et moins le joueur fera attention, en plus vu qu'il y en aura enormement, il fera encore moins attention a chaque unique zombie. Cool ca!
# ##################### PAGE #####################
#   c un battle royale francais?
# ##################### PAGE #####################

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

persist_directory = "./../../../saved/saved_model/"

vectordb = Chroma.from_documents(documents = sub_docs, embedding = HuggingFaceEmbeddings(), persist_directory = persist_directory)
print("Database generated")

vectordb.persist()
print("Database saved")
# Out:
# Using embedded DuckDB with persistence: data will be stored in: ./../../../saved/saved_model/
# Database generated
# Database saved

# %%
similar_search_test = vectordb.similarity_search_with_score("Tu aimes les zombies ?", k=10)
print("################# similar search results #################")
for (item, score) in similar_search_test:
    print(score, item.page_content)
print("##########################################################")
# Out:
# ################# similar search results #################
# 0.5215572118759155 Ou alors, tu trouve ta propre facon de nommer les zombies.
# 0.5256391167640686 Tes zombies sont vraiment trop cool mec
# 0.5517427921295166 <@!234336151782162432> veut des zombies nus
# 0.5870147943496704 Et maintenant Les Zombies sont enfin dans UE4! On va bientot pouvoir faire joujou
# 0.6112480163574219 Par contre, si tu veux mettre 1000 zombies, ca doit se faire, par contre bonne chance :>
# 0.6121604442596436 Ah ouais d'accord. Ca fait reference  un Zombie debile quoi XD
# 0.622271716594696 y a des noms cool l-dedans, famine ou starvation (pour les anglophones) j'aime particulierement. le Fuck Up Zombies x), le Giselle Project XD.
# 0.6245781183242798 C'est vrai ouais, je suis pas dans ce theme en fait.Malgre que l'idee est cool! Hmm ca aussi c'est pas mal. Des mots qui evoque le terme Zombie...
# 0.6495230793952942 "Un Zombie presque parfait !" ?
# 0.6554479002952576 Alors moi j'ai une question, on va jouer le zombie ou le survivant ?
# ##########################################################
